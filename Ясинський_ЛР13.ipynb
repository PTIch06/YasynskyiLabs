# %% [markdown]
# <a href="https://colab.research.google.com/github/PTIch06/YasynskyiLabs/blob/main/%D0%AF%D1%81%D0%B8%D0%BD%D1%81%D1%8C%D0%BA%D0%B8%D0%B9_%D0%9B%D0%A013.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Лабораторна робота №13
# ##з дисципліни "Технології обробки природомовної інформації"
# ###студента групи КН-31/2
# ###Ясинського Дениса
# ###Варіант №22

# %%
import nltk
import re

nltk.download('gutenberg')
nltk.download('brown')
nltk.download('state_union')
nltk.download('names')
nltk.download('wordnet')
nltk.download('general_words')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package state_union to /root/nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Package names is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Error loading general_words: Package 'general_words' not
# [nltk_data]     found in index
# False

# %% [markdown]
# ☼ Create a variable phrase containing a list of words. Review the operations described in the previous chapter, including addition, multiplication, indexing, slicing, and sorting.(для списку слів виконати додавання, множення, індексування, розрізання та сортування)

# %%
# 1
words = ['Something', 'rare', 'make', 'pover', 'java', 'apple', 'cat']
print(words+words)
print(words*3)
print(words[1])
print(words[-3:])
print(sorted(w.lower() for w in set(words)))
# Out:
# ['Something', 'rare', 'make', 'pover', 'java', 'apple', 'cat', 'Something', 'rare', 'make', 'pover', 'java', 'apple', 'cat']
# ['Something', 'rare', 'make', 'pover', 'java', 'apple', 'cat', 'Something', 'rare', 'make', 'pover', 'java', 'apple', 'cat', 'Something', 'rare', 'make', 'pover', 'java', 'apple', 'cat']
# rare
# ['java', 'apple', 'cat']
# ['apple', 'cat', 'java', 'make', 'pover', 'rare', 'something']

# %% [markdown]
# ☼ Use the corpus module to explore austen-persuasion.txt. How many word tokens does this book have? How many word types(кількість лексем та слів)

# %%
austen_persuasion = gutenberg.words('austen-persuasion.txt')
print(len(austen_persuasion))
print(len(set(austen_persuasion)))
# Out:
# 98171
# 6132

# %% [markdown]
# ☼Use the Brown corpus reader nltk.corpus.brown.words() or the Web text corpus reader nltk.corpus.webtext.words() to access some sample text in two different genres.(доступ до словників)

# %%
religion = brown.words(categories='religion')
religion
# Out:
# ['As', 'a', 'result', ',', 'although', 'we', 'still', ...]

# %%
hobbies = brown.words(categories='hobbies')
hobbies
# Out:
# ['Too', 'often', 'a', 'beginning', 'bodybuilder', ...]

# %% [markdown]
# ☼ Read in the texts of the State of the Union addresses, using the state_union corpus reader. Count occurrences of men, women, and people in each document. What has happened to the usage of these words over time?(підрахувати кількість чоловіків/жінок по документах)

# %%
print(state_union.fileids())
# Out:
# ['1945-Truman.txt', '1946-Truman.txt', '1947-Truman.txt', '1948-Truman.txt', '1949-Truman.txt', '1950-Truman.txt', '1951-Truman.txt', '1953-Eisenhower.txt', '1954-Eisenhower.txt', '1955-Eisenhower.txt', '1956-Eisenhower.txt', '1957-Eisenhower.txt', '1958-Eisenhower.txt', '1959-Eisenhower.txt', '1960-Eisenhower.txt', '1961-Kennedy.txt', '1962-Kennedy.txt', '1963-Johnson.txt', '1963-Kennedy.txt', '1964-Johnson.txt', '1965-Johnson-1.txt', '1965-Johnson-2.txt', '1966-Johnson.txt', '1967-Johnson.txt', '1968-Johnson.txt', '1969-Johnson.txt', '1970-Nixon.txt', '1971-Nixon.txt', '1972-Nixon.txt', '1973-Nixon.txt', '1974-Nixon.txt', '1975-Ford.txt', '1976-Ford.txt', '1977-Ford.txt', '1978-Carter.txt', '1979-Carter.txt', '1980-Carter.txt', '1981-Reagan.txt', '1982-Reagan.txt', '1983-Reagan.txt', '1984-Reagan.txt', '1985-Reagan.txt', '1986-Reagan.txt', '1987-Reagan.txt', '1988-Reagan.txt', '1989-Bush.txt', '1990-Bush.txt', '1991-Bush-1.txt', '1991-Bush-2.txt', '1992-Bush.txt', '1993-Clinton.txt
# ...

# %%
cfd = nltk.ConditionalFreqDist((target,fileid[:4])for fileid in state_union.fileids() for w in state_union.words(fileid) for target in  ['men','women'] if w.lower().startswith(target))
cfd
# Out:
# ConditionalFreqDist(nltk.probability.FreqDist,
#                     {'men': FreqDist({'1945': 2,
#                                '1946': 16,
#                                '1947': 8,
#                                '1948': 5,
#                                '1949': 2,
#                                '1950': 6,
#                                '1951': 9,
#                                '1953': 5,
#                                '1954': 4,
#                                '1955': 9,
#                                '1956': 5,
#                                '1957': 7,
#                                '1958': 3,
#                                '1959': 5,
#                                '1960': 2,
#                                '1961': 6,
#                                '1962': 7,
#                                '1963': 14,
#                                '1964': 3,
#                                '1965': 22,
#                                '1966': 14,
# ...

# %% [markdown]
# ☼ In the discussion of comparative wordlists, we created an object called translate which you could look up using words in both German and Spanish in order to get corresponding words in English. What problem might arise with this approach? Can you suggest a way to avoid this problem?

# %%
#слова, які пишуться однаково по Німецьки та по Іспанськи

# %% [markdown]
# ◑ Define a conditional frequency distribution over the Names corpus that allows you to see which initial letters are more frequent for males vs. females (cf. 4.4).

# %%
cfd = nltk.ConditionalFreqDist(
  (fileid, name[1])
    for fileid in names.fileids()
      for name in names.words(fileid))
cfd.plot()

# %% [markdown]
# ◑ What percentage of noun synsets have no hyponyms? You can get all noun synsets using wn.all_synsets('n') (Який відсоток синсетів іменників не має гіпонімів)

# %%
nounsH=[noun for noun in wn.all_synsets('n') if len(noun.hyponyms())==0]
nouns=[noun for noun in wn.all_synsets('n')]
print(len(nounsH)/len(nouns)*100)
# Out:
# 79.67119283931072

# %% [markdown]
# ◑ Write a program to find all words that occur at least three times in the Brown Corpus(Слова зустрічаються > 3p)

# %%
words=nltk.FreqDist(brown.words())
atleast_3times=[word for word in set(brown.words()) if words[word]>2]
print(atleast_3times)
# Out:
# ['allies', 'Brahms', 'obedience', 'with', 'erratic', 'wrought', 'psychopathic', 'container', 'maintenance', 'presence', 'chain', 'Behind', 'bushes', '1963', 'roaming', 'silenced', 'retiring', 'culture', 'Fifty', 'managerial', 'evaluation', 'beauties', 'eternal', 'Philharmonic', 'Dickey', 'comprehending', 'diagnose', 'drought', 'Bruckner', 'consisting', 'lock', 'contraction', 'shivered', 'transpiration', 'ago', 'sexual', 'Congo', 'beneath', 'Ltd.', 'adventures', 'Koreans', 'Fear', 'vapor', 'Wheelock', 'Jason', 'Colman', 'staining', 'prison', 'Parkersburg', 'cocktail', 'finale', 'ghastly', 'Minnie', 'diet', 'Brain', 'Reaching', 'Passing', 'foot', 'pastel', 'bereavement', 'conjoined', 'seating', 'Neutral', 'warns', "poet's", 'grinning', 'Rebels', 'Today', 'reasoning', 'marketed', 'invitations', 'dice', 'sliding', 'Agricultural', 'involve', 'Road', 'physiological', 'guessing', 'literalness', 'checklist', "Rourke's", 'Muslim', 'Columbia', 'Breath', 'Angelina', 'fabrication', 'conspicuousl
# ...

# %% [markdown]
# ◑ Write a program to create a table of word frequencies by genre, like the one given in 1 for modals. Choose your own words and try to find words whose presence (or absence) is typical of a genre. Discuss your findings. (частота слів за жанрами)

# %%
cfd = nltk.ConditionalFreqDist((genre,word)for genre in brown.categories() for word in brown.words(categories=genre))
genres = ["love", "hate", "death", "life", "marriage", "work", "children","magic"]
cfd.tabulate(conditions=brown.categories(), samples=genres)
# Out:
#                     love     hate    death     life marriage     work children    magic
#       adventure        9        8       20       29        4       31        9        1
#  belles_lettres       68        4       57      182       12      118       33        6
#       editorial       13        0       21       35        4       30       32        3
#         fiction       16        9       17       44        1       32       20        2
#      government        1        0        2       14        4       44        2        0
#         hobbies        6        0        3       36        0       87       18        1
#           humor        4        0        1       12        2       13       20        0
#         learned       13        2       21       69       14      117       76        2
#            lore       19        2       26       73       21       85       48        1
#         mystery        7        2       18       21        6       33        6        0
# ...

# %% [markdown]
# ◑ Write a function word_freq() that takes a word and the name of a section of the Brown Corpus as arguments, and computes the frequency of the word in that section of the corpus. (приймає слово, обчислює його частоту у розділі)

# %%
category_text=brown.words(categories='news')
print(sum(1 for wd in category_text if wd=='work'))
# Out:
# 66

# %% [markdown]
# ◑ Define a function hedge(text) which processes a text and produces a new version with the word 'like' between every third word.(додати like між кожним третім словом)

# %%
text = 'something random to test this task before uploading somethere'.split()
ids = [index-1 for index in list(range(3,len(text)+4,3))]
for id in ids:
  text.insert(id,'like')
print(text)
# Out:
# ['something', 'random', 'like', 'to', 'test', 'like', 'this', 'task', 'like', 'before', 'uploading', 'like', 'somethere']
